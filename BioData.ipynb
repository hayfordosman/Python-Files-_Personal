# %%
# how to connect Google colab to your Google Drive

# %%
print(" Reading all your Data form Google drive")
# Out:
#  Reading all your Data form Google drive

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
print("To read your data from Google Drive use the code below")
# Out:
# To read your data from Google Drive use the code below

# %%
import pandas as pd
data=pd.read_csv("/content/drive/My Drive/Bio.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-2b796c740f13> in <module>()
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("/content/drive/My Drive/Bio.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data
# Out:
#     Gender  FSIQ  VIQ  PIQ  Weight  Height  Salary
# 0     Male    50  120  115     102    64.5     250
# 1   Female    60  130  130     112    85.2     650
# 2   Female    70  140  145     122   105.9    1050
# 3   Female    80  150  160     132   126.6    1450
# 4     Male    90  160  175     142   147.3    1850
# 5     Male   100  170  190     152   168.0    2250
# 6   Female   110  180  205     162   188.7    2650
# 7     Male   120  190  220     172   209.4    3050
# 8     Male   130  200  235     182   230.1    3450
# 9   Female   140  210  250     192   250.8    3850
# 10  Female   150  220  265     202   271.5    4250

# %%
data.describe()
# Out:
#              FSIQ         VIQ         PIQ      Weight      Height       Salary
# count   11.000000   11.000000   11.000000   11.000000   11.000000    11.000000
# mean   100.000000  170.000000  190.000000  152.000000  168.000000  2250.000000
# std     33.166248   33.166248   49.749372   33.166248   68.654133  1326.649916
# min     50.000000  120.000000  115.000000  102.000000   64.500000   250.000000
# 25%     75.000000  145.000000  152.500000  127.000000  116.250000  1250.000000
# 50%    100.000000  170.000000  190.000000  152.000000  168.000000  2250.000000
# 75%    125.000000  195.000000  227.500000  177.000000  219.750000  3250.000000
# max    150.000000  220.000000  265.000000  202.000000  271.500000  4250.000000

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-047ed65ff157> in <module>()
# ----> 1 data.shape
#
# NameError: name 'data' is not defined

# %%
import statistics

# %%
from numpy.ma.core import mean
mean(data.FSIQ)
# Out:
# 100.0

# %%
print(data)
# Out:
#     Gender  FSIQ  VIQ  PIQ  Weight  Height  Salary
# 0     Male    50  120  115     102    64.5     250
# 1   Female    60  130  130     112    85.2     650
# 2   Female    70  140  145     122   105.9    1050
# 3   Female    80  150  160     132   126.6    1450
# 4     Male    90  160  175     142   147.3    1850
# 5     Male   100  170  190     152   168.0    2250
# 6   Female   110  180  205     162   188.7    2650
# 7     Male   120  190  220     172   209.4    3050
# 8     Male   130  200  235     182   230.1    3450
# 9   Female   140  210  250     192   250.8    3850
# 10  Female   150  220  265     202   271.5    4250

# %%
import pandas as pd
d=pd.read_csv("/content/drive/My Drive/DataBank/CD.csv")

# %%
print(d)
# Out:
#          ID                          SCh_Name State         City FirstName  \
# 0    1023.0  Affordable Truck Driver Training    AL      Moulton     Wanda
# 1    1024.0    American Truck Driving Academy    AL  Phenix City       Dee
# 2    1025.0                   Bevill State CC    AL      Sumiton       NaN
# 3    1026.0    Bishop State Community College    AL       Chatom     Steve
# 4    1027.0                      Bishop State    AL       Mobile      Brad
# ..      ...                               ...   ...          ...       ...
# 475     NaN                               NaN   NaN          NaN       NaN
# 476     NaN                               NaN   NaN          NaN       NaN
# 477     NaN                               NaN   NaN          NaN       NaN
# 478     NaN                               NaN   NaN          NaN       NaN
# 479     NaN                               NaN   NaN          NaN       NaN
#
#     LastName        Phone      Tution   Unnamed: 8
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of     Gender  FSIQ  VIQ  PIQ  Weight  Height  Salary
# 0     Male    50  120  115     102    64.5     250
# 1   Female    60  130  130     112    85.2     650
# 2   Female    70  140  145     122   105.9    1050
# 3   Female    80  150  160     132   126.6    1450
# 4     Male    90  160  175     142   147.3    1850
# 5     Male   100  170  190     152   168.0    2250
# 6   Female   110  180  205     162   188.7    2650
# 7     Male   120  190  220     172   209.4    3050
# 8     Male   130  200  235     182   230.1    3450
# 9   Female   140  210  250     192   250.8    3850
# 10  Female   150  220  265     202   271.5    4250>

# %%
# note file_name.head()

# %%
print("To view all the packages in the Python program, type !pip list as shown below")
# Out:
# To view all the packages in the Python program, type !pip list as shown below

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------------
# absl-py                       1.0.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.2.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.11.4
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.4.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        4.1.0
# blis                          0.4.1
# bokeh                         2.3.3
# Bottleneck                    1.3.4
# ...

# %% [markdown]
# # Introduction to GreatLearning Python

# %% [markdown]
# To write mathematical equation in Google Colab, start with write them in between two dallar sign.

# %% [markdown]
# $ax^+bx+c $

# %% [markdown]
# Always select text and click on the last icon with three verticall columns

# %% [markdown]
# $x = \frac{-b + sqrt(b^2 - 4ac)}{2a}$

# %%
num=3

# %%
num
# Out:
# 3

# %%
x=y=z=r=50

# %%
x
# Out:
# 50

# %%
y
# Out:
# 50

# %%
z
# Out:
# 50

# %%
r
# Out:
# 50

# %% [markdown]
# In Python, it is not mandatory to assign a value to declare a variable. True/Fales Ans: False
#
# 2. You are reading Python code, and these statements appear at different locations in the code:
#
# Studentid = 002
# .
# .
# .
# studentId = 002
# .
# .
# .
# StudentId = 002
#
# Answer choices
#
# Select only one option
#
# A: All three statements refer to different variables.
#
# B: All three statements refer to the same variable.
#
# The correct answer is A
