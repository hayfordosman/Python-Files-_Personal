# %%
import pandas as pd

# %%
Dada= pd.read_csv("https://github.com/hayfordosman/Data-Banks/blob/main/TData1.csv")
# Out:
#   File "<ipython-input-3-4b8083132b34>", line 1
#     Dada= pd.read_csv(https://github.com/hayfordosman/Data-Banks/blob/main/TData1.csv)
#                            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
url = "https://github.com/hayfordosman/Data-Banks/blob/main/TData1.csv"

# %%
dad=pd.read_csv(url)
kb=pd.read_csv("https://github.com/hayfordosman/Data-Banks/blob/main/TData1.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-4cf204c521f5> in <module>()
# ----> 1 dad=pd.read_csv(url)
#       2 kb=pd.read_csv("https://github.com/hayfordosman/Data-Banks/blob/main/TData1.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
from google.colab import drive
drive.mount("/gdrive")
Bio/gdrive
