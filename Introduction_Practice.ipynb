# %%
num=30

# %%
num
# Out:
# 30

# %%
x,y,z,r,=10,51,23,45

# %%
x
y
z
r
# Out:
# 45

# %%
print(x)
print(y)
print(z)
print(r)
# Out:
# 10
# 51
# 23
# 45

# %% [markdown]
# Introduction to Python

# %%
num=3
num
# Out:
# 3

# %%
num=400
num
# Out:
# 400

# %% [markdown]
# Code block is multiple codes lines in pytho examples:

# %%
x=(1,2,3,4,5,6,6)
print(x)
print(sum(x))
print(max(x))
# Out:
# (1, 2, 3, 4, 5, 6, 6)
# 27
# 6

# %% [markdown]
# Line of Code/Single codes

# %%
x=y=z=r=100

# %%
x
# Out:
# 100

# %%
y
# Out:
# 100

# %%
z
# Out:
# 100

# %%
r
# Out:
# 100

# %% [markdown]
# Note the following:
# In python, if you create blocks of code, run will excecute only the last line but print will print all lines of codes.

# %%
# for example

# %%
a=(10,25,32,14,52)
b=("Great Learning")
c=("Hayord", "Osumanu", "Steven")
a
b
c
# Out:
# ('Hayord', 'Osumanu', 'Steven')

# %%
# Using print syntax returns everything

# %%
print(a)
print(b)
print(c)
print(sum(a))
# Out:
# (10, 25, 32, 14, 52)
# Great Learning
# ('Hayord', 'Osumanu', 'Steven')
# 133

# %%
# the best way to present the above code is:

# %%
print("The value of a is:",a)
print("The value of b is:", b)
print("The value of c is",c)
# Out:
# The value of a is: (10, 25, 32, 14, 52)
# The value of b is: Great Learning
# The value of c is ('Hayord', 'Osumanu', 'Steven')

# %%
# note your can also create the above example in the following way:

# %%
p,t,q,s=(20,30,15,24,65,21),("Hayford","Osumanu","Steven","Boateng"),(25,32,45,35,45,12),("Great","Learning", "Varible Assignment ")

# %%
p
# Out:
# (20, 30, 15, 24, 65, 21)

# %%
t
# Out:
# ('Hayford', 'Osumanu', 'Steven', 'Boateng')

# %%
q
# Out:
# (25, 32, 45, 35, 45, 12)

# %%
s
# Out:
# ('Great', 'Learning', 'Varible Assignment ')

# %%
# However note

# %%
p
q
r
s
# Out:
# ('Great', 'Learning', 'Varible Assignment ')

# %% [markdown]
# ## 1.3 Good Practices of Naming **Variables** **bold text** bold text

# %%
# Rule for naming in Python

# %%
# Out:
#   File "<ipython-input-37-bab3d9988152>", line 1
#     print(Lowercase letter l and uppercase letter O may lead to confusion. Why? The first could be mistaken for a number 1, and the second for a number 0. In fact, you may have just mistaken those as you read that! The takeaway is to use care when using these characters or avoid them altogether.
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# Python Variable Naming
# 1. **Lowercase letter "i"** and **uppercase letter "O"** may lead to confusion. Why? The first could be mistaken for a number 1, and the second for a number 0. In fact, you may have just mistaken those as you read that! The takeaway is to use care when using these characters or avoid them altogether.
#
# 2. The characters that are allowed for variable names are **letters**, **underscores,** and **numbers**.
#
# 3. The *variable name can not begin with a number*, however. *Underscores are good for adding readability*. For example, this_variable is easier to read than thisvariable.
#
# 4. It’s good to keep variable names as short as you can while still conveying the purpose of the variable. For example, member is a better choice than m for a variable.
#
# 4.(b). Along that same thought process, best_choice is better than bc for a variable name. You want to know what the variable is for, but not have names that are out of control. the_best_member_of_the_group_is_what_is_held_in_this_variable is valid, but probably not a good choice for a variable name.
#
# 5. *Don’t try to use spaces or any whitespace character in variable names*. You can use the underscore as we saw above for better readability.
# Python has many dedicated function names and keywords.
#
# You need to be aware of what those are so that you don’t try to use any of them as variable names in your program! These are reserved for specific uses in the Python language.

# %%
# Do not use the following in variable names

# %% [markdown]
# Don’t use any of these for variable names!
# and	       except	      lambda	      with
# as	       finally	    nonlocal	    while
# assert	   false	      None	        yield
# break	     for	        not	          try
# class	     from	        or	          is
# continue	 global	      pass	        else
# def	       if / elif  	raise	        True
# del	       import	      return	      in

# %% [markdown]
# **1.4 Integer, Float, and Complex**

# %%
a=200
type(a)
# Out:
# int

# %%
# int are both positive and negative whole numbers

# %%
b=2.52
type(b)
# Out:
# float

# %%
# float = are floating points or integers and decimals or fractions

# %%
b1=160000000
type(b1)
# Out:
# int

# %%
b2=1.6e4
print(b2)
# Out:
# 16000.0

# %%
type(b2)
# Out:
# float

# %%
# note 160000 are int but 1.6e5 are float

# %%
r=16000
s=1.6e4
print(type(r))
print(type(s))
# Out:
# <class 'int'>
# <class 'float'>

# %%
a=2+5j
type(a)
# Out:
# complex

# %% [markdown]
# ## 1.5 Operations or Calculation on Strings

# %%
str1=("Great")
str2=("Learning")
str1+str2
# Out:
# 'GreatLearning'

# %%
# This is called Concatenation or adding two strings in python

# %%
# exponents in Strings

# %%
b="Hay"
b*8
# Out:
# 'HayHayHayHayHayHayHayHay'

# %%
z="Hayford"

# %%
z[0]
# Out:
# 'H'

# %%
z[1]
# Out:
# 'a'

# %%
z[3]
# Out:
# 'f'

# %%
# z["positions"]

# %%
# z[m:n]  note  m=positions and n=number of characters

# %%
z[0:3]
# Out:
# 'Hay'

# %%
z[:5]
# Out:
# 'Hayfo'

# %%
z[:-3]
# Out:
# 'Hayf'

# %%
z[-3:]
# Out:
# 'ord'

# %%
z[-1:1]
# Out:
# ''

# %% [markdown]
# ## 1.6 Boolean Data Type

# %%
var=True
type(var)
# Out:
# bool

# %%
# When a code is highlighted, then its an inbuild code

# %%
a=10
b=50
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
# Note the following

# %%
10>50
# Out:
# False

# %%
10<50
# Out:
# True

# %%
a=10
b=50
b>b
type(a>b)
# Out:
# bool

# %%
# convert int into float

# %%
a=10
type(a)
# Out:
# int

# %%
type(float(a))
# Out:
# float

# %%
float(10)
# Out:
# 10.0

# %% [markdown]
# ## 1.7 Changing Variable types

# %%
# float into int

# %%
int(12.33333)
# Out:
# 12

# %%
int(3.895)
# Out:
# 3

# %%
float("15")
# Out:
# 15.0

# %%
a="10"

# %%
b="5"

# %%
a+b
# Out:
# '105'

# %%
float(a+b)
# Out:
# 105.0

# %%
float(45)
# Out:
# 45.0

# %% [markdown]
# ## 1.8 Print Statement

# %%
x=7
y=9
print("x=",x)
print("y=",y)
# Out:
# x= 7
# y= 9

# %%
# print command allows python to print all command

# %%
x=7
y=9
x
y
# Out:
# 9

# %%
x=7
y=9
print("x=",x,end="\n\n")
print("y=",y)
# Out:
# x= 7
#
# y= 9

# %%
print(("hayford\n\n"))
print(("Osumanu"))
# Out:
# hayford
#
#
# Osumanu

# %%
print(("hayford\n"))
print(("Osumanu"))
# Out:
# hayford
#
# Osumanu

# %%
print(("hayford"))
print(("Osumanu"))
# Out:
# hayford
# Osumanu

# %%
x=100

# %%
x
# Out:
# 100

# %% [markdown]
# Date:04/12/2022

# %% [markdown]
# ## 1.9 User Inpurt

# %%
Name=print(input("What is your Name?"))
# Out:
# What is your Name?Hayford
# Hayford

# %%
age=int(input("Please enter your name:"))
print(age)
type(age)
# Out:
# Please enter your name:44
# 44
# int

# %%
name=str(input("What is your name? "))
print(name)
type(name)
# Out:
# What is your name? Hayford Osumanu
# Hayford Osumanu
# str

# %%
weight=float(input("Enter your weight: "))
# Out:
# Enter your weight: 150

# %% [markdown]
# ## 1.10 Arithmetic Operators

# %%
# Additions Operations (+)

# %%
x=10
y=25
print("The sum of 10 and 25 is:",x+y)
# Out:
# The sum of 10 and 25 is: 35

# %%
# Subtraction Operations (-)

# %%
x=250
y=100
print("The difference between 250 and 100 is:", x-y)
# Out:
# The difference between 250 and 100 is: 150

# %%
# Multiplication Operations (*)

# %%
a=35
b=15
print("The product of 35 and 15 is:",a*b)
# Out:
# The product of 35 and 15 is: 525

# %%
# Division Operations (/)

# %%
x=2500
y=100
print("The value of 2500 divided by 100 is:",x/y)
# Out:
# The value of 2500 divided by 100 is: 25.0

# %%
# Exponential Operations (**)

# %%
x=3
y=5
print(x**5)
# Out:
# 243

# %%
print("5 raised to the power 2 is:",y**2)
# Out:
# 5 raised to the power 2 is: 25

# %%
print(x**10/y**2)
# Out:
# 2361.96

# %%
# Remainder Operations (%)

# %% [markdown]
# If you are only interested in the remainder, use the percentage sign as division sign.

# %%
x=15
y=7
print("if you divide 15 by 7 the remainder is:",x%y)
# Out:
# if you divide 15 by 7 the remainder is: 1

# %%
# Quotient Operations (//)  (int part of divisions)

# %% [markdown]
# If you are interested in the only the whole number part of divisions, then use double slash sign //

# %%
x=25
y=7
print(x//y)
# Out:
# 3

# %%
# examples

# %%
print("if a=35 and b=15 then:")
print("a+b =",a+b)
print("a-b =",a-b)
print("a*b =",a*b)
print("a/b =",a/b)
print("a**b =",a**b)
print("a%b =",a%b)
print("a//b =",a//b)
# Out:
# if a=35 and b=15 then:
# a+b = 110
# a-b = 40
# a*b = 2625
# a/b = 2.142857142857143
# a**b = 423783671008921674551342233250306179570543463341891765594482421875
# a%b = 5
# a//b = 2

# %%
# Rounding   note: the code is Round(operations, dp)

# %%
a=35
b=15
round(a/b,2)
# Out:
# 2.33

# %% [markdown]
# ## 1.11 comparison of Operators

# %%
# Greater than Operations (>)

# %%
x=75
y=35
print("x is greater than y, True/False? ",x>y)
# Out:
# x is greater than y, True/False?  True

# %%
# Less than Operations (<)

# %%
print("x is less than than y, True/False? ",x<y)
# Out:
# x is less than than y, True/False?  False

# %%
# Equal Operations (==)

# %%
print("x is equal to y, True/False ",x==y)
# Out:
# x is equal to y, True/False  False

# %%
# Not Equal Operations (!=)

# %%
print("x is not equal to y, True/False ",x!=y)
# Out:
# x is not equal to y, True/False  True

# %%
# Grater or equal to (>=)

# %%
print("x is not greater or equal to y, True/Fale ",x>=y)
# Out:
# x is not greater or equal to y, True/Fale  True

# %%
# Less or Equal to (<=)

# %%
print("x is less or equal to y, True/False ",x<=y)
# Out:
# x is less or equal to y, True/False  False

# %%
# Examples

# %%
print("if a=75 and b=35")
print("x>y = ", x>y)
print("x<y = ", x<y)
print("x==y = ", x==y)
print("x!=y = ", x!=y)
print("x==y = ", x==y)
print("x>=y = ", x>=y)
print("x<=y = ", x<=y)
# Out:
# if a=75 and b=35
# x>y =  True
# x<y =  False
# x==y =  False
# x!=y =  True
# x==y =  False
# x>=y =  True
# x<=y =  False

# %% [markdown]
# # 1.12 Assignment of Operators

# %%
# in a loop coding we use the folloing assignment

# %%
x=3
y=5

# %%
print("if x=3 and y=5, then: ")
print("the updated vlaue of x=x+2 is",x+2)
# Out:
# if x=3 and y=5, then:
# the updated vlaue of x=x+2 is 37

# %%
print("The updated value of y after is:",y+8)
# Out:
# The updated value of y after is: 23

# %%
# Note the following

# %%
i=5
i*=10
print("The updated value of i is:",i)
# Out:
# The updated value of i is: 50

# %%
print("the updated values of the is:")
# Out:
# the updated values of the is:

# %%
i-=5
print(i)
# Out:
# 40

# %%
i/=10
print(i)
# Out:
# 4.0

# %% [markdown]
# # 1.13 Logical Operators

# %%
# using AND and OR Operators

# %%
a=11
b=20

# %%
x=a>b and b>a

# %%
print(x)
# Out:
# False

# %%
y=a<b or b==20

# %%
print(y)
# Out:
# True
