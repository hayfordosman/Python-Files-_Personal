# %%
import pandas as pd

# %%
from google.colab import files

# %%
file= files.upload()
# Out:
#      <input type="file" id="files-1d88db4d-d9cc-468a-ba1c-e69f1ebb8a97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d88db4d-d9cc-468a-ba1c-e69f1ebb8a97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Bio.csv to Bio.csv

# %%
import pandas as pd

# %%
d= pd.read_csv("Bio.csv")

# %%
d.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ  Weight  Height  Salary
# 0    Male    50  120  115     102    64.5     250
# 1  Female    60  130  130     112    85.2     650
# 2  Female    70  140  145     122   105.9    1050
# 3  Female    80  150  160     132   126.6    1450
# 4    Male    90  160  175     142   147.3    1850

# %%
from google.colab import files

# %%
drive.mount("/gdrive")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ae127a2eb088> in <module>()
# ----> 1 drive.mount("/gdrive")
#
# NameError: name 'drive' is not defined

# %%
from googl.colab import drive
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-9511b0948712> in <module>()
# ----> 1 from googl.colab import drive
#
# ModuleNotFoundError: No module named 'googl'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

# %%
d= pd.read_csv("/content/drive/My Drive/DataBank/USData.csv")

# %%
d.Abbreviation
# Out:
# 0     AL
# 1     AK
# 2     AZ
# 3     AR
# 4     CA
# 5     CO
# 6     CT
# 7     DE
# 8     FL
# 9     GA
# 10    HI
# 11    ID
# 12    IL
# 13    IN
# 14    IA
# 15    KS
# 16    KY
# 17    LA
# 18    ME
# 19    MD
# 20    MA
# 21    MI
# 22    MN
# 23    MS
# 24    MO
# 25    MT
# 26    NE
# 27    NV
# 28    NH
# 29    NJ
# 30    NM
# 31    NY
# 32    NC
# 33    ND
# 34    OH
# 35    OK
# 36    OR
# 37    PA
# 38    RI
# 39    SC
# 40    SD
# 41    TN
# 42    TX
# 43    UT
# 44    VT
# 45    VA
# 46    WA
# 47    WV
# 48    WI
# 49    WY
# Name: Abbreviation, dtype: object

# %%
import pandas as pd

# %%
url="https://github.com/hayfordosman/Data-Banks/blob/main/StoreData.csv"

# %%
daa= pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-25-e1cd03900506> in <module>()
# ----> 1 daa= pd.read_csv(url)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
daa= pd.read_csv("https://github.com/hayfordosman/Data-Banks/blob/main/StoreData.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-23-2eccea69d66e> in <module>()
# ----> 1 daa= pd.read_csv("https://github.com/hayfordosman/Data-Banks/blob/main/StoreData.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
p= pd.read_csv("Bio.csv")

# %%
p
# Out:
#     Gender  FSIQ  VIQ  PIQ  Weight  Height  Salary
# 0     Male    50  120  115     102    64.5     250
# 1   Female    60  130  130     112    85.2     650
# 2   Female    70  140  145     122   105.9    1050
# 3   Female    80  150  160     132   126.6    1450
# 4     Male    90  160  175     142   147.3    1850
# 5     Male   100  170  190     152   168.0    2250
# 6   Female   110  180  205     162   188.7    2650
# 7     Male   120  190  220     172   209.4    3050
# 8     Male   130  200  235     182   230.1    3450
# 9   Female   140  210  250     192   250.8    3850
# 10  Female   150  220  265     202   271.5    4250

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

# %%
da= pd.read_csv("/content/drive/My Drive/DataBank/USData.csv")

# %%
da.columns
# Out:
# Index(['State', 'Abbreviation', 'Income', 'TotArea', 'LandArea', 'WaterArea',
#        'Density', '2022 Pop.', ' FY19GDPQ2', 'FY20GDPQ1', 'FY20GDPQ2', 'Name',
#        'Party', 'Date assumed office'],
#       dtype='object')

# %%
da.describe()
# Out:
#           State Abbreviation    Income TotArea LandArea WaterArea Density  \
# count        50           50        50      50       50        50      50
# unique       50           50        50      50       50        50      48
# top     Alabama           AL  $69,842   52,420   50,645     1,775      58
# freq          1            1         1       1        1         1       3
#
#         2022 Pop.  FY19GDPQ2  FY20GDPQ1  FY20GDPQ2      Name       Party  \
# count          50         50         50         50        50          50
# unique         50         50         50         50        50           2
# top     4,949,697  47,101.93  47,704.78  43,557.83  Kay Ivey  Republican
# freq            1          1          1          1         1          28
#
#        Date assumed office
# count                   50
# unique                  30
# top              7/11/1905
# freq                     6

# %%
import pandas as pd

# %%
Data= pd.read_csv("https://github.com/hayfordosman/Data-Bank/blob/main/GOOG.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-38-30b5dcac4873> in <module>()
# ----> 1 Data= pd.read_csv("https://github.com/hayfordosman/Data-Bank/blob/main/GOOG.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
